# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data source: https://www.kaggle.com/varpit94/goldman-sachs-stock-data-updated-till-1jul2021

# %%
gs_data = pd.read_csv('GS.csv')

# %%
gs_data.head()
# Out:
#          Date     Open    High      Low    Close  Adj Close    Volume
# 0  1999-05-04  76.0000  77.250  70.0000  70.3750  54.440052  22320900
# 1  1999-05-05  69.8750  69.875  66.2500  69.1250  53.473076   7565700
# 2  1999-05-06  68.0000  69.375  67.0625  67.9375  52.554470   2905700
# 3  1999-05-07  67.9375  74.875  66.7500  74.1250  57.340931   4862300
# 4  1999-05-10  73.3750  73.500  70.2500  70.6875  54.681774   2589400

# %%
gs_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
gs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5577 entries, 0 to 5576
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5577 non-null   object
#  1   Open       5577 non-null   float64
#  2   High       5577 non-null   float64
#  3   Low        5577 non-null   float64
#  4   Close      5577 non-null   float64
#  5   Adj Close  5577 non-null   float64
#  6   Volume     5577 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 305.1+ KB

# %%
gs_data.isnull().values.any()
# Out:
# False

# %%
gs_data['Date'] = pd.to_datetime(gs_data['Date'])

# %%
gs_data = gs_data.set_index(gs_data['Date'])

# %%
gs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5577 entries, 1999-05-04 to 2021-06-30
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5577 non-null   datetime64[ns]
#  1   Open       5577 non-null   float64
#  2   High       5577 non-null   float64
#  3   Low        5577 non-null   float64
#  4   Close      5577 non-null   float64
#  5   Adj Close  5577 non-null   float64
#  6   Volume     5577 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 348.6 KB

# %%
gs_data['Open'].describe()
# Out:
# count    5577.000000
# mean      153.388107
# std        59.548650
# min        54.000000
# 25%        99.375000
# 50%       155.300003
# 75%       194.839996
# max       393.000000
# Name: Open, dtype: float64

# %%
gs_data['High'].describe()
# Out:
# count    5577.000000
# mean      155.255690
# std        59.940215
# min        54.540001
# 25%       101.070000
# 50%       157.000000
# 75%       197.399994
# max       393.260010
# Name: High, dtype: float64

# %%
gs_data['Low'].describe()
# Out:
# count    5577.000000
# mean      151.518473
# std        59.125804
# min        47.410000
# 25%        97.809998
# 50%       153.720001
# 75%       192.449997
# max       387.549988
# Name: Low, dtype: float64

# %%
gs_data['Close'].describe()
# Out:
# count    5577.000000
# mean      153.413700
# std        59.536651
# min        52.000000
# 25%        99.300003
# 50%       155.330002
# 75%       194.970001
# max       391.450012
# Name: Close, dtype: float64

# %%
gs_data['Adj Close'].describe()
# Out:
# count    5577.000000
# mean      134.953673
# std        60.874014
# min        43.174923
# 25%        81.400467
# 50%       134.594437
# 75%       173.237244
# max       391.450012
# Name: Adj Close, dtype: float64

# %%
gs_data['Volume'].describe()
# Out:
# count    5.577000e+03
# mean     5.347931e+06
# std      6.154837e+06
# min      1.076000e+05
# 25%      2.525500e+06
# 50%      3.598300e+06
# 75%      5.660900e+06
# max      1.145907e+08
# Name: Volume, dtype: float64

# %%
plt.plot(gs_data['Open'])

# %%
plt.plot(gs_data['High'])

# %%
plt.plot(gs_data['Low'])

# %%
plt.plot(gs_data['Close'])

# %%
plt.plot(gs_data['Adj Close'])

# %%
plt.plot(gs_data['Volume'])
